# %%
import seaborn as sns

# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('car_price.csv')

# %%
df.head()
# Out:
#     mon_year  KM_driven Fuel_Type  Horse_Power         Color Transmission  \
# 0   Oct_2006      49805    Diesel           90      Metallic       Manual
# 1   Oct_2006      77313    Diesel           90      Metallic       Manual
# 2  Sept_2006      44214    Diesel           90      Metallic       Manual
# 3   Jul_2006      50880    Diesel           90  Non-Metallic       Manual
# 4   Mar_2006      40810    Diesel           90  Non-Metallic       Manual
#
#    Engine  Doors  Cylinders  Gears  Sport_Model  selling_price
# 0    2000      3          4      5            0          14310
# 1    2000      3          4      5            0          14575
# 2    2000      3          4      5            0          14787
# 3    2000      3          4      5            0          15847
# 4    2000      3          4      5            0          14575

# %%
df.columns
# Out:
# Index(['mon_year', 'KM_driven', 'Fuel_Type', 'Horse_Power', 'Color',
#        'Transmission', 'Engine', 'Doors', 'Cylinders', 'Gears', 'Sport_Model',
#        'selling_price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mon_year       1436 non-null   object
#  1   KM_driven      1436 non-null   int64
#  2   Fuel_Type      1436 non-null   object
#  3   Horse_Power    1436 non-null   int64
#  4   Color          1436 non-null   object
#  5   Transmission   1436 non-null   object
#  6   Engine         1436 non-null   int64
#  7   Doors          1436 non-null   int64
#  8   Cylinders      1436 non-null   int64
#  9   Gears          1436 non-null   int64
#  10  Sport_Model    1436 non-null   int64
#  11  selling_price  1436 non-null   int64
# dtypes: int64(8), object(4)
# memory usage: 134.8+ KB

# %%
df.isna().sum()
# Out:
# mon_year         0
# KM_driven        0
# Fuel_Type        0
# Horse_Power      0
# Color            0
# Transmission     0
# Engine           0
# Doors            0
# Cylinders        0
# Gears            0
# Sport_Model      0
# selling_price    0
# dtype: int64

# %%
print(df['Transmission'])
# Out:
# 0       Manual
# 1       Manual
# 2       Manual
# 3       Manual
# 4       Manual
#          ...
# 1431    Manual
# 1432    Manual
# 1433    Manual
# 1434    Manual
# 1435    Manual
# Name: Transmission, Length: 1436, dtype: object

# %%
var = df['Transmission']
print(var.value_counts())
# Out:
# Transmission
# Manual       1356
# Automatic      80
# Name: count, dtype: int64

# %%
#df['Transmission'] = pd.get_dummies(df['Transmission'],drop_first=True)  # if the values output as True or False restart the kernel

# %%
plt.figure(figsize=(8,8))
a = ['Manual','Automatic']
plt.subplot(2,2,1)
myexplode = [0.2,0]
plt.pie(df['Transmission'].value_counts(),labels=a,explode=myexplode,autopct="%1.1f%%")
plt.subplot(2,2,2)
label = ['Petrol','Diesel','CNG']
myexplode = [0.3,0.2,0]
plt.pie(df['Fuel_Type'].value_counts(),labels=label,explode=myexplode,shadow=True,autopct="%1.1f%%")
plt.subplot(2,2,3)
b=['Metallic','Non-Metallic']
myexplode = [0,0.14]
plt.pie(df['Color'].value_counts(),labels=b,explode=myexplode,autopct="%1.1f%%")
plt.show()

# %%
print(df['Fuel_Type'].value_counts())
# Out:
# Fuel_Type
# Petrol    1264
# Diesel     155
# CNG         17
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mon_year       1436 non-null   object
#  1   KM_driven      1436 non-null   int64
#  2   Fuel_Type      1436 non-null   object
#  3   Horse_Power    1436 non-null   int64
#  4   Color          1436 non-null   object
#  5   Transmission   1436 non-null   object
#  6   Engine         1436 non-null   int64
#  7   Doors          1436 non-null   int64
#  8   Cylinders      1436 non-null   int64
#  9   Gears          1436 non-null   int64
#  10  Sport_Model    1436 non-null   int64
#  11  selling_price  1436 non-null   int64
# dtypes: int64(8), object(4)
# memory usage: 134.8+ KB

# %%
print(df['Color'].value_counts())
# Out:
# Color
# Metallic        969
# Non-Metallic    467
# Name: count, dtype: int64

# %%
#df['Fuel_Type'] = pd.get_dummies(df['Fuel_Type'],drop_first=1)  # if the values output as True or False restart the kernel
# dfx=df
# dfx.info()
dfx = pd.read_csv('car_price.csv')

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()
dfx['Transmission']= label_encoder.fit_transform(dfx['Transmission'])

dfx['Transmission'].unique()
# Out:
# array([1, 0])

# %%
print(dfx['Transmission'].value_counts())
print(df['Transmission'].value_counts())
# Out:
# Transmission
# 1    1356
# 0      80
# Name: count, dtype: int64
# Transmission
# Manual       1356
# Automatic      80
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mon_year       1436 non-null   object
#  1   KM_driven      1436 non-null   int64
#  2   Fuel_Type      1436 non-null   object
#  3   Horse_Power    1436 non-null   int64
#  4   Color          1436 non-null   object
#  5   Transmission   1436 non-null   object
#  6   Engine         1436 non-null   int64
#  7   Doors          1436 non-null   int64
#  8   Cylinders      1436 non-null   int64
#  9   Gears          1436 non-null   int64
#  10  Sport_Model    1436 non-null   int64
#  11  selling_price  1436 non-null   int64
# dtypes: int64(8), object(4)
# memory usage: 134.8+ KB

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mon_year       1436 non-null   object
#  1   KM_driven      1436 non-null   int64
#  2   Fuel_Type      1436 non-null   object
#  3   Horse_Power    1436 non-null   int64
#  4   Color          1436 non-null   object
#  5   Transmission   1436 non-null   int32
#  6   Engine         1436 non-null   int64
#  7   Doors          1436 non-null   int64
#  8   Cylinders      1436 non-null   int64
#  9   Gears          1436 non-null   int64
#  10  Sport_Model    1436 non-null   int64
#  11  selling_price  1436 non-null   int64
# dtypes: int32(1), int64(8), object(3)
# memory usage: 129.1+ KB

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()
dfx['Color']= label_encoder.fit_transform(dfx['Color'])

dfx['Color'].unique()
# Out:
# array([0, 1])

# %%
print(df['Color'].value_counts())
print(dfx['Color'].value_counts())
# Out:
# Color
# Metallic        969
# Non-Metallic    467
# Name: count, dtype: int64
# Color
# 0    969
# 1    467
# Name: count, dtype: int64

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()
dfx['Fuel_Type']= label_encoder.fit_transform(dfx['Fuel_Type'])

dfx['Fuel_Type'].unique()
# Out:
# array([1, 2, 0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mon_year       1436 non-null   object
#  1   KM_driven      1436 non-null   int64
#  2   Fuel_Type      1436 non-null   object
#  3   Horse_Power    1436 non-null   int64
#  4   Color          1436 non-null   object
#  5   Transmission   1436 non-null   object
#  6   Engine         1436 non-null   int64
#  7   Doors          1436 non-null   int64
#  8   Cylinders      1436 non-null   int64
#  9   Gears          1436 non-null   int64
#  10  Sport_Model    1436 non-null   int64
#  11  selling_price  1436 non-null   int64
# dtypes: int64(8), object(4)
# memory usage: 134.8+ KB

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mon_year       1436 non-null   object
#  1   KM_driven      1436 non-null   int64
#  2   Fuel_Type      1436 non-null   int32
#  3   Horse_Power    1436 non-null   int64
#  4   Color          1436 non-null   int32
#  5   Transmission   1436 non-null   int32
#  6   Engine         1436 non-null   int64
#  7   Doors          1436 non-null   int64
#  8   Cylinders      1436 non-null   int64
#  9   Gears          1436 non-null   int64
#  10  Sport_Model    1436 non-null   int64
#  11  selling_price  1436 non-null   int64
# dtypes: int32(3), int64(8), object(1)
# memory usage: 117.9+ KB

# %%
dfx.columns
# Out:
# Index(['mon_year', 'KM_driven', 'Fuel_Type', 'Horse_Power', 'Color',
#        'Transmission', 'Engine', 'Doors', 'Cylinders', 'Gears', 'Sport_Model',
#        'selling_price'],
#       dtype='object')

# %%
dfx=dfx.drop(labels=['mon_year'],axis=1) # 1 represents the columns and 0-rows

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   KM_driven      1436 non-null   int64
#  1   Fuel_Type      1436 non-null   int32
#  2   Horse_Power    1436 non-null   int64
#  3   Color          1436 non-null   int32
#  4   Transmission   1436 non-null   int32
#  5   Engine         1436 non-null   int64
#  6   Doors          1436 non-null   int64
#  7   Cylinders      1436 non-null   int64
#  8   Gears          1436 non-null   int64
#  9   Sport_Model    1436 non-null   int64
#  10  selling_price  1436 non-null   int64
# dtypes: int32(3), int64(8)
# memory usage: 106.7 KB

# %%
dfx.head()
# Out:
#    KM_driven  Fuel_Type  Horse_Power  Color  Transmission  Engine  Doors  \
# 0      49805          1           90      0             1    2000      3
# 1      77313          1           90      0             1    2000      3
# 2      44214          1           90      0             1    2000      3
# 3      50880          1           90      1             1    2000      3
# 4      40810          1           90      1             1    2000      3
#
#    Cylinders  Gears  Sport_Model  selling_price
# 0          4      5            0          14310
# 1          4      5            0          14575
# 2          4      5            0          14787
# 3          4      5            0          15847
# 4          4      5            0          14575

# %%
df.head()
# Out:
#     mon_year  KM_driven Fuel_Type  Horse_Power         Color Transmission  \
# 0   Oct_2006      49805    Diesel           90      Metallic       Manual
# 1   Oct_2006      77313    Diesel           90      Metallic       Manual
# 2  Sept_2006      44214    Diesel           90      Metallic       Manual
# 3   Jul_2006      50880    Diesel           90  Non-Metallic       Manual
# 4   Mar_2006      40810    Diesel           90  Non-Metallic       Manual
#
#    Engine  Doors  Cylinders  Gears  Sport_Model  selling_price
# 0    2000      3          4      5            0          14310
# 1    2000      3          4      5            0          14575
# 2    2000      3          4      5            0          14787
# 3    2000      3          4      5            0          15847
# 4    2000      3          4      5            0          14575

# %%
dfx.columns
# Out:
# Index(['KM_driven', 'Fuel_Type', 'Horse_Power', 'Color', 'Transmission',
#        'Engine', 'Doors', 'Cylinders', 'Gears', 'Sport_Model',
#        'selling_price'],
#       dtype='object')

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,2,1)
plt.title('Fuel_Type')
plt.hist(df['Fuel_Type'])
plt.subplot(2,2,2)
plt.title('Color')
plt.hist(df['Color'])
plt.subplot(2,2,3)
plt.title('Engine')
plt.hist(df['Engine'])
plt.subplot(2,2,4)
plt.title('Transmission')
plt.hist(df['Transmission'])
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(data=df,x='KM_driven',y='selling_price')
plt.show()

# %%
dfx=dfx.drop(labels=['Cylinders'],axis=1) # 1 represents the columns and 0-rows

# %%
sns.heatmap(dfx.corr(),annot=True,fmt='.2f')
plt.show()

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   KM_driven      1436 non-null   int64
#  1   Fuel_Type      1436 non-null   int32
#  2   Horse_Power    1436 non-null   int64
#  3   Color          1436 non-null   int32
#  4   Transmission   1436 non-null   int32
#  5   Engine         1436 non-null   int64
#  6   Doors          1436 non-null   int64
#  7   Gears          1436 non-null   int64
#  8   Sport_Model    1436 non-null   int64
#  9   selling_price  1436 non-null   int64
# dtypes: int32(3), int64(7)
# memory usage: 95.5 KB

# %%
dfx.isna().sum()
# Out:
# KM_driven        0
# Fuel_Type        0
# Horse_Power      0
# Color            0
# Transmission     0
# Engine           0
# Doors            0
# Gears            0
# Sport_Model      0
# selling_price    0
# dtype: int64

# %%
dfx.columns
# Out:
# Index(['KM_driven', 'Fuel_Type', 'Horse_Power', 'Color', 'Transmission',
#        'Engine', 'Doors', 'Gears', 'Sport_Model', 'selling_price'],
#       dtype='object')

# %%
df['Horse_Power'].unique()
# Out:
# array([ 90, 192,  69, 110,  97,  71, 116,  98,  86,  72, 107,  73],
#       dtype=int64)

# %%
sns.pairplot(dfx)

# %%
dfx.columns
# Out:
# Index(['KM_driven', 'Fuel_Type', 'Horse_Power', 'Color', 'Transmission',
#        'Engine', 'Doors', 'Gears', 'Sport_Model', 'selling_price'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))
sns.histplot(df['selling_price'],kde=True,color='b')
# Out:
# <Axes: xlabel='selling_price', ylabel='Count'>

# %%
dfx.columns
# Out:
# Index(['KM_driven', 'Fuel_Type', 'Horse_Power', 'Color', 'Transmission',
#        'Engine', 'Doors', 'Gears', 'Sport_Model', 'selling_price'],
#       dtype='object')

# %%
def bar_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
columns_plot = ['Color','Gears','Sport_Model']

# %%
for i in columns_plot:
    bar_plot(i)
# Out:
# Color:
#  Color
# Metallic        969
# Non-Metallic    467
# Name: count, dtype: int64
# Gears:
#  Gears
# 5    1390
# 6      43
# 3       2
# 4       1
# Name: count, dtype: int64
# Sport_Model:
#  Sport_Model
# 0    1005
# 1     431
# Name: count, dtype: int64

# %%
df['Sport_Model'].value_counts()
# Out:
# Sport_Model
# 0    1005
# 1     431
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mon_year       1436 non-null   object
#  1   KM_driven      1436 non-null   int64
#  2   Fuel_Type      1436 non-null   object
#  3   Horse_Power    1436 non-null   int64
#  4   Color          1436 non-null   object
#  5   Transmission   1436 non-null   object
#  6   Engine         1436 non-null   int64
#  7   Doors          1436 non-null   int64
#  8   Cylinders      1436 non-null   int64
#  9   Gears          1436 non-null   int64
#  10  Sport_Model    1436 non-null   int64
#  11  selling_price  1436 non-null   int64
# dtypes: int64(8), object(4)
# memory usage: 134.8+ KB

# %%
df.columns
# Out:
# Index(['mon_year', 'KM_driven', 'Fuel_Type', 'Horse_Power', 'Color',
#        'Transmission', 'Engine', 'Doors', 'Cylinders', 'Gears', 'Sport_Model',
#        'selling_price'],
#       dtype='object')

# %%
plt.bar(df['Color'],df['selling_price'])
plt.xlabel('Color')
plt.ylabel('Selling price')
plt.show()

# %%
sns.lmplot(x='KM_driven',y='selling_price',data=df)

# %%
sns.scatterplot(x='Engine',y='selling_price',data=df)
# Out:
# <Axes: xlabel='Engine', ylabel='selling_price'>

# %%
df.columns
# Out:
# Index(['mon_year', 'KM_driven', 'Fuel_Type', 'Horse_Power', 'Color',
#        'Transmission', 'Engine', 'Doors', 'Cylinders', 'Gears', 'Sport_Model',
#        'selling_price'],
#       dtype='object')

# %%
plt.bar(df['Gears'],df['Horse_Power'])
plt.xlabel('Gears')
plt.ylabel('Horse_Power')
plt.show()

# %%
df.columns
# Out:
# Index(['mon_year', 'KM_driven', 'Fuel_Type', 'Horse_Power', 'Color',
#        'Transmission', 'Engine', 'Doors', 'Cylinders', 'Gears', 'Sport_Model',
#        'selling_price'],
#       dtype='object')

# %%
df["Year"] = df["mon_year"].str.split("_").str[1].astype(int)  # Extracting year
df_yearly = df.groupby("Year", as_index=False)["selling_price"].mean()
plt.figure(figsize=(8, 5))
sns.lineplot(x="Year", y="selling_price", data=df_yearly, marker="o")
plt.title("Year vs Selling Price Trend")
plt.xlabel("Year")
plt.ylabel("Average Selling Price")
plt.grid(True)
plt.show()
